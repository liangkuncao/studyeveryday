# %% [markdown]
# processes > threads > coroutines
# processes have seperate resource, threads belong to a specific process and share access to common resources, and coroutine

# %% [markdown]
# # Multiple Processes

# %%
from multiprocessing import Process

def print_func(continent: str = '', count: int = 1) -> None:
    for i in range(count):
        print(i, ': ', continent)
    
if __name__ == '__main__':
    names = ['Americaq', 'Europe', 'Africa']
    procs = []
    
    for name in names:
        proc = Process(target=print_func, args=(name, 100))
        procs.append(proc)
        proc.start()
#         proc.join()
    
    for proc in procs:
        proc.join()
# Out:
# 0 :  Americaq
# 1 :  Americaq
# 0 :  Europe
# 2 :  Americaq
# 1 :  Europe
# 3 :  Americaq
# 2 :  Europe
# 0 :  Africa
# 4 :  Americaq
# 3 :  Europe
# 5 :  Americaq
# 1 :  Africa
# 6 :  Americaq
# 4 :  Europe
# 2 :  Africa
# 5 :  Europe
# 7 :  Americaq
# 3 :  Africa
# 8 :  Americaq
# 6 :  Europe
# 4 :  Africa
# 7 :  Europe
# 9 :  Americaq
# 5 :  Africa
# 8 :  Europe
# 10 :  Americaq
# 11 :  Americaq
# 9 :  Europe
# 6 :  Africa
# 12 :  Americaq
# 10 :  Europe
# 7 :  Africa
# 11 :  Europe
# 13 :  Americaq
# 8 :  Africa
# 14 :  Americaq
# 12 :  Europe
# 9 :  Africa
# 15 :  Americaq
# 13 :  Europe
# 10 :  Africa
# 16 :  Americaq
# 14 :  Europe
# 11 :  Africa
# 17 :  Americaq
# 15 :  Europe
# 12 :  Africa
# 18 :  Americaq
# 16 :  Europe
# 13 :  Africa
# 19 :  Americaq
# 14 :  Africa
# 17 :  Europe
# 20 :  Americaq
# 18 :  Europe
# 15 :  Africa
# 19 :  Europe
# 21 :  Americaq
# 16 :  Africa
# 22 :  Americaq
# 17 :  Africa
# 20 :  Europe
# 23 :  Americaq
# 21 :  Europe
# 18 :  Africa
# ...

# %% [markdown]
# # Multiple Threads

# %%
import threading
 
def print_cube(num):
    """
    function to print cube of given num
    """
    print("Cube: {}".format(num * num * num))
def print_square(num):
    """
    function to print square of given num
    """
    print("Square: {}".format(num * num))
if __name__ == "__main__":
    # creating thread
    t1 = threading.Thread(target=print_square, args=(10,))
    t2 = threading.Thread(target=print_cube, args=(10,))
 
    # starting thread 1
    t1.start()
    # starting thread 2
    t2.start()
 
    # wait until thread 1 is completely executed
    t1.join()
    # wait until thread 2 is completely executed
    t2.join()
 
    # both threads completely executed
    print("Done!")
# Out:
# Square: 100
# Cube: 1000
# Done!

# %% [markdown]
# # Multiple Coroutines

# %%
def print_name(prefix):
    print("Searching prefix: {}".format(prefix))
    try:
        while True:
            name = (yield)
            if prefix in name:
                print(name)
    except GeneratorExit:
        print("Closing coroutine!!")
        
corou = print_name("Dear")
corou.__next__()
corou.send("James")
corou.send("Dear James")
corou.send("Dear James")
# Out:
# Closing coroutine!!
# Searching prefix: Dear
# Dear James
# Dear James
