# %%
from typing import List, Dict
from collections import Counter
import math

import matplotlib.pyplot as plt

def bucketize(point: float, bucket_size: float) -> float:
    """Floor the point to the next lower multiple of bucket_size"""
    return bucket_size * math.floor(point / bucket_size)

def make_histogram(points: List[float], bucket_size: float) -> Dict[float, int]:
    return Counter(bucketize(point, bucket_size) for point in points)

def plot_histogram(points: List[float], bucket_size: float, title: str = ""):
    histogram = make_histogram(points, bucket_size)
    plt.bar(histogram.keys(), histogram.values(), width=bucket_size)
    plt.title(title)

# %%
import numpy as np

random.seed(0)

uniform = [200 * np.random.random() - 100 for _ in range(10000)]
normal = np.random.normal(loc=0, scale=57, size=10000)

# %%
plot_histogram(uniform, 10, "Uniform Histogram")

# %%
plot_histogram(normal, 10, "Normal Histogram")

# %%
xs = [np.random.standard_normal() for _ in range(1000)]
ys1 = [x + np.random.standard_normal() / 2 for x in xs]
ys2 = [-x + np.random.standard_normal() / 2 for x in xs]

# %%
plot_histogram(xs, 0.1)

# %%
plot_histogram(ys1, 0.1)

# %%
plot_histogram(ys2, 0.1)

# %%
plt.scatter(xs, ys1, marker='.', c='black', label='ys1')
plt.scatter(xs, ys2, marker='.', c='gray', label='ys2')
plt.xlabel('xs')
plt.ylabel('ys')
plt.legend(loc=9)
plt.title("Very Different Joing Distributions")
plt.show()

# %%
print(np.corrcoef(xs, ys1)[0, 1])
print(np.corrcoef(xs, ys2)[0, 1])
# Out:
# 0.8936583835284592
# -0.899804094431967
